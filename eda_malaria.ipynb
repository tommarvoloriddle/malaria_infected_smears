# %% [markdown]
# <a href="https://colab.research.google.com/github/tommarvoloriddle/Coursera---Convolutional-Neural-Networks-deeplearning.ai-/blob/main/tumor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/nageshsinghc4/Brain-Tumor-Detection-using-Mask-R-CNN.git
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 28845 (delta 2), reused 2 (delta 1), pack-reused 28840
# Receiving objects: 100% (28845/28845), 476.03 MiB | 40.77 MiB/s, done.
# Resolving deltas: 100% (20467/20467), done.
# Checking out files: 100% (7148/7148), done.

# %%
# %cd datasets/
# Out:
# /content/datasets

# %%
# !pip3 install tensorflow_datasets

# %%
import tensorflow_datasets as tfds
ds, ds_info = tfds.load('malaria_infected_smears', split='train', with_info=True)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# ...
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...
# Shuffling and writing examples to /root/tensorflow_datasets/malaria_infected_smears/1.0.0.incompleteKVFHZI/malaria_infected_smears-train.tfrecord
# ...

# %%
build(ds_info, ds)
